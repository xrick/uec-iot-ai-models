# %% [markdown]
# ## 測試項目
# 1. 訓練集中的alarm聲
# 2. 使用pruned and quantized tflite model
# 4. export to cc file

# %%
import os
import sys
import datetime
import shutil
import numpy as np
import tensorflow as tf
# from tensorflow import keras
import zipfile
import wavio
import random
from common import utils as U
np.set_printoptions(threshold=sys.maxsize)
# Out:
# WARNING:tensorflow:From C:\Users\UEC\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sys.path.append(os.path.abspath("../../src"))
sys.path.append(os.path.abspath("../../src/deployment/"))
sys.path.append(os.path.abspath("../../"))

# %%
from lib_original.bytes import to_bytes, from_bytes, byte_conversion_tests, load_data, load_raw, save_raw, save_scores
from lib_original.constants import quant_support, crops, feature_count
# from lib_original.quantize import quantization_tests, get_cast

# %%
from datetime import datetime
import re

# %%
def quantize_int8(x, axis):
  '''Quantization into int8_t precision, operating on x along axis'''
  scaling_factor_shape = tuple(np.append([len(x)],np.ones(x.ndim - 1, dtype = int)))
  epsilon = 0.000000001
  x_scaling_factor = (np.max(np.abs(x), axis) / 128) + epsilon
  x_scaling_factor = x_scaling_factor.reshape(scaling_factor_shape)
  # x_zero_offset = -0.5 #-0.25 #-0.25
  result = (x / x_scaling_factor) #+ x_zero_offset
  return np.rint(result).astype(np.int8)

# %%
# mask8 = 0x4000 # >> 8 : 16384
# mask7 = 0x2000 # >> 7 :  8192
# mask6 = 0x1000 # >> 6 :  4096
# mask5 = 0x0800 # >> 5 :  2048
# mask4 = 0x0400 # >> 4 :  1024
# mask3 = 0x0200 # >> 3 :   512
# mask2 = 0x0100 # >> 2 :   256
# mask1 = 0x0080 # >> 1 :   128
# mask0 = 0x0040 # >> 0 :    64 below the value, drop the value

# %%
# def maskOP(x):
#     x = np.int16(x)
#     print(f"begin:x:{x}")
#     if (mask8&x):
#         return x >> 8
#     elif (mask7&x):
#         return x >> 7
#     elif (mask6&x):
#         return x >> 6
#     elif (mask5&x):
#         return x >> 5
#     elif (mask4&x):
#         return x >> 4
#     elif (mask3&x):
#         return x >> 3
#     elif (mask2&x):
#         return x >> 2
#     elif (mask1&x):
#         return x >> 1
#     elif (mask0&x):
#         return x
#     else:
#         return 0;

# %%
# def quantize_int8(x, axis):
#     len_of_x = len(x[0][0][0])
#     print(f"len_of_x:{len_of_x}")
#     for i in range(len_of_x):
#         nflag = 2; #positive
#         print("{}:{}".format(i,x[0][0][0][i]))
#         tmp_x = x[0][0][0][i]
#         if tmp_x < 0:
#             tmp_x = np.abs(tmp_x)
#             nflag = 1
#         tmp_x = maskOP(tmp_x)
#         if(nflag==1):
#             tmp_x = -1 * (tmp_x)
#         print("{}:{}".format(i,x[0][0][0][i]))
#         print("*********************************")
#         x[0][0][0][i] = tmp_x
#     return np.rint(x).astype(np.int8)

# %% [markdown]
# ### Loading TFlite Model

# %%
tflite_quant_model_path = "../../trained_models/step_6_QAT_and_Convert2TFLite/final_qat_model_lr0.01_testacc91_20240507011044/qat_model_valacc92.7_tracc_82.9_prunInfo_0.8_0.85_ds_ver4home_20240507011044.tflite";
# tflite_quant_model_path = "../../trained_models/step_6_QAT_and_Convert2TFLite/final_qat_model_lr0.01_testacc90.68_202405062253/qat_model_valacc92.7_tracc_82.9_prunInfo_0.8_0.85_ds_ver4home_20240506220725.tflite";
# tflite_quant_model_path = "./models/tflite/quant_retrained_model_0.85compress_acc_95.4_20240207150608_128.tflite";
# Load quantized TFLite model
tflite_interpreter_quant = tf.lite.Interpreter(model_path=tflite_quant_model_path)

# %%
# model.summary()
input_details = tflite_interpreter_quant.get_input_details()
output_details = tflite_interpreter_quant.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

tflite_interpreter_quant.allocate_tensors();
# Out:
# == Input details ==
# name: input.2_te_transform
# shape: [    1     1 30225     1]
# type: <class 'numpy.int8'>
#
# == Output details ==
# name: Xq.1
# shape: [1 3]
# type: <class 'numpy.int8'>

# %%
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def getFileList(srcDir,regex='.*\.wav'):
    results = os.listdir(srcDir)
    out_files = []
    cnt_files = 0
    for file in results:
        if os.path.isdir(os.path.join(srcDir, file)):
            out_files += getFileList(os.path.join(srcDir, file))
        elif re.match(regex, file,  re.I):  # file.startswith(startExtension) or file.endswith(".txt") or file.endswith(endExtension):
            out_files.append(os.path.join(srcDir, file))
            cnt_files = cnt_files + 1
    return out_files

# %% [markdown]
# ## sound preprocessing functions

# %%
_inputLen = 30225
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess_debug():
    debug_funcs = []
    debug_funcs += [U.padding( _inputLen// 2),
              # U.normalize(32768.0),]
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return debug_funcs


def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)
    return sound;
    

def padding(pad):
    def f(sound):
        return np.pad(sound, pad, 'constant')

    return f
    

def random_crop(size):
    def f(sound):
        org_size = len(sound)
        start = random.randint(0, org_size - size)
        return sound[start: start + size]

#     return f

# %%
_funcs = preprocess_setup()
# _debug_funcs = preprocess_debug()

# %% [markdown]
# ### Read Test Wav File

# %%
#specify the input type:
dtype = 'int8'

positive_moan_test_wavs = "../test_sounds/test_sounds_alarm_moan/positive/moaning/"
# negative_test_wavs_others = "./test_sounds/negative/othersounds/"
# negative_test_wavs_siren = "./test_sounds/negative/siren/"



# p_wav_list = getFileList(positive_test_wavs);
p_moan_wav_list = getFileList(positive_moan_test_wavs);
# n_wav_list_other = getFileList(negative_test_wavs_others);
# n_wav_list_siren = getFileList(negative_test_wavs_siren);
# print(f"total alarm sounds:{len(p_wav_list)} ");
# print(f"total other sounds:{len(n_wav_list_other)}")
# print(f"total siren sounds:{len(n_wav_list_siren)}")
print(f"total moaning sounds:{len(p_moan_wav_list)}")
p_moan_label = 56;
p_label = 52;
n_label = 99;

sounds_1 = [];
labels_1 = [];
# sounds_2 = [];
# labels_2 = [];

## moaning sounds ##
for i in p_moan_wav_list:
    sound = wavio.read(i).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1]
    label = int(p_moan_label);
    if len(sound)> 220500:
        sound = sound[:220500]
    # if len(sound)> 30225:
    #     sound = sound[:30226]
    sound = preprocess(sound, _funcs);
    sounds_1.append(sound);
    labels_1.append(label);
    # sounds_2.append(sound);
    # labels_2.append(label);

## sound = preprocess(sound, _funcs)
# for i in p_wav_list:
#     sound = wavio.read(i).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1]
#     label = int(p_label);
#     if len(sound)> 220500:
#         sound = sound[:220500]
#     sound = preprocess(sound, _funcs);
#     sounds_1.append(sound);
#     labels_1.append(label);
#     sounds_2.append(sound);
#     labels_2.append(label);
    
# for j in n_wav_list_other:
#     sound = wavio.read(j).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1];
#     label = int(n_label);
#     sound = np.int16(preprocess(sound, _funcs));
#     # print(sound) # to see the sound is float or int
#     sounds_1.append(sound);
#     labels_1.append(label);

# for k in n_wav_list_siren:
#     sound = wavio.read(j).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1];
#     label = int(n_label);
#     sound = np.int16(preprocess(sound, _funcs));
#     sounds_1.append(sound);
#     labels_1.append(label);
#     sounds_2.append(sound);
#     labels_2.append(label);

# print(f"sound testset 1 length: {len(sounds_1)}");
# print(f"sound testset 2 length: {len(sounds_2)}");

# sound = wavio.read(test_sound_file).data.T[0]
# start = sound.nonzero()[0].min()
# end = sound.nonzero()[0].max()
# sound = sound[start: end + 1]  # Remove silent sections
# label = 18 #int(os.path.splitext(test_sound_file)[0].split('-')[-1])

# if len(sound)> 220500:
#     sound = sound[:220500]

# ec50_sound1 =  wavio.read(ec50_18_sound).data.T[0]
# start_ec50 = ec50_sound1.nonzero()[0].min()
# end_ec50 = ec50_sound1.nonzero()[0].max()
# ec50_sound1 = ec50_sound1[start_ec50:end_ec50+1]
# ec50_18_label = 18
# Out:
# total moaning sounds:96

# %%
moaning_len = len(sounds_1);
# test2_len = len(sounds_2)
# len_alarm = len(p_wav_list);
# len_siren = len(n_wav_list_siren);
# len_other = len(n_wav_list_other);
# n_total_len = len_other + len_siren ;
# s_total_len = len(n_wav_list_siren);
# print(f"total alarm sounds is {len_alarm}\ntotal other sounds is {n_total_len}(other:{len_other} + siren:{len_siren})");
print(f"total moaning sounds is {moaning_len}\n");
moaning_correct_num = 0;
pred_other_num = 0;
# test2_correct_num = 0;
# test1_p_correct_num = 0;
# test2_p_correct_num = 0;
# n_correct_num = 0;
# n_correct_siren_num = 0;
# n_correct_othersounds_num = 0;

for w in range(moaning_len): 
    s = sounds_1[w]
    l = labels_1[w]
    s_test = np.expand_dims(s[0], axis=0);
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    #get_cast(dtype)(sound, axis = -2)
    # s_test = np.int8(s_test);
    # s_test = get_cast(dtype)(s_test, axis=-2)
    s_test = quantize_int8(s_test,axis=-2)
    
    tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter_quant.invoke()
    pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
    # print(f"Prediction result shape:{pred.shape}\n");
    print(f"Prediction result: {pred}, and true label: {l}")
    if l == 56: #positive
        if pred[0][1] > pred[0][0] and pred[0][1] > pred[0][2]:
            moaning_correct_num += 1;
            
    # if l != 56: #negative
    if pred[0][1] < pred[0][0] or pred[0][1]<pred[0][2]:
        pred_other_num += 1;
print(f"test 1 all wav files is {moaning_len},\n correct predict moaning:{100*(moaning_correct_num/moaning_len)}\n not predict moaning is {100*(pred_other_num/moaning_len)}");
print("   ******************   test-1 end   ******************   ")
# print("   ******************   test-2 begin (only test domestic alarm and out-door siren)   ******************   ")
# for w in range(test2_len): 
#     s = sounds_2[w]
#     l = labels_2[w]
#     s_test = np.expand_dims(s[0], axis=0);
#     s_test = np.expand_dims(s_test, axis=1);
#     s_test = np.expand_dims(s_test, axis=3);
#     # s_test = np.float32(s_test);
#     #simple use type cast
#     # s_test = np.int8(s_test)
#     # s_test = get_cast(dtype)(s_test, axis=-2)
#     s_test = quantize_int8(s_test,axis=-2)
    
#     # print(s_test.shape)
#     # print(f"the {w+1} item's shape:\n  {s.shape}");
#     # Run inference
#     # print(f"s type:{type(s)}, and s shape:{s.shape}")
#     tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
#     tflite_interpreter_quant.invoke()
#     pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
#     # print(f"Prediction result shape:{pred.shape}\n");
#     print(f"Prediction result: {pred}, and true label: {l}")
#     if l == 52: #positive
#         if pred[0][0] > pred[0][1]:
#             test2_correct_num += 1;
#             test2_p_correct_num += 1;
#     if l == 99: #negative
#         if pred[0][0] < pred[0][1]:
#             test2_correct_num += 1;
#             n_correct_siren_num += 1;
# print(f"test1: total sounds(alarm+other+siren)test result is {100*(test1_correct_num/test1_len)}");
# print(f"test1: total alarm sounds result is {100*(test1_p_correct_num/len_alarm)}");
# print(f"test1 total other sounds(other+siren) result is {100*n_correct_num/n_total_len}");
# print("**************************************************************************************")
# print(f"test2: total sounds(alarm+siren)test result is {100*(test2_correct_num/test2_len)}")
# print(f"test1: total alarm sounds result is {100*(test2_p_correct_num/len_alarm)}");
# print(f"test2 total siren sounds result is {100*n_correct_siren_num/len_siren}");
# Out:
# total moaning sounds is 96
#
# Prediction result: [[ 7  7 36]], and true label: 56
# Prediction result: [[-30  39  48]], and true label: 56
# Prediction result: [[-43  59  41]], and true label: 56
# Prediction result: [[19 16 17]], and true label: 56
# Prediction result: [[ 24  49 -18]], and true label: 56
# Prediction result: [[-52  88  25]], and true label: 56
# Prediction result: [[-37  64  30]], and true label: 56
# Prediction result: [[-40  64  35]], and true label: 56
# Prediction result: [[-49  96  15]], and true label: 56
# Prediction result: [[-19  79   0]], and true label: 56
# Prediction result: [[-36  80  16]], and true label: 56
# Prediction result: [[-20  83  -3]], and true label: 56
# Prediction result: [[-39  98   1]], and true label: 56
# Prediction result: [[-84  78  67]], and true label: 56
# Prediction result: [[-44  23  77]], and true label: 56
# Prediction result: [[-45  96   9]], and true label: 56
# Prediction result: [[-24   7  71]], and true label: 56
# Prediction result: [[-54  56  55]], and true label: 56
# Prediction result: [[-46  37  64]], and true label: 56
# Prediction result: [[-43  74  28]], and true label: 56
# Prediction result: [[-54  79  34]], and true label: 56
# Prediction result: [[-11   8  57]], and true label: 56
# Prediction result: [[ 59 -10   3]], and true label: 56
# Prediction result: [[ 55 -10   6]], and true label: 56
# Prediction result: [[-62 113  12]], and true label: 56
# Prediction result: [[-47  73  33]], and true label: 56
# Prediction result: [[-12  26  39]], and true label: 56
# Prediction result: [[-17  88 -11]], and true label: 56
# Prediction result: [[-39  84  14]], and true label: 56
# Prediction result: [[-58 101  19]], and true label: 56
# Prediction result: [[-25  66  16]], and true label: 56
# Prediction result: [[-68 100  30]], and true label: 56
# Prediction result: [[-29  83   6]], and true label: 56
# Prediction result: [[-34  84  10]], and true label: 56
# Prediction result: [[-41  88  12]], and true label: 56
# Prediction result: [[-23  39  38]], and true label: 56
# Prediction result: [[-25  42  38]], and true label: 56
# Prediction result: [[-46  91  16]], and true label: 56
# Prediction result: [[-46  95  13]], and true label: 56
# Prediction result: [[-41  55  43]], and true label: 56
# Prediction result: [[-67 103  26]], and true label: 56
# Prediction result: [[-48  61  44]], and true label: 56
# Prediction result: [[-26  31  50]], and true label: 56
# Prediction result: [[-33  67  24]], and true label: 56
# Prediction result: [[-21  72   7]], and true label: 56
# Prediction result: [[-9 24 38]], and true label: 56
# Prediction result: [[-42 101   3]], and true label: 56
# Prediction result: [[-41 100   2]], and true label: 56
# Prediction result: [[ 3 59 -5]], and true label: 56
# Prediction result: [[-33 102  -9]], and true label: 56
# Prediction result: [[-16  89 -14]], and true label: 56
# Prediction result: [[-14  58  13]], and true label: 56
# Prediction result: [[-11  54  12]], and true label: 56
# Prediction result: [[-27  44  40]], and true label: 56
# Prediction result: [[-50  71  38]], and true label: 56
# Prediction result: [[-23  36  41]], and true label: 56
# Prediction result: [[-19  41  35]], and true label: 56
# Prediction result: [[-37  80  16]], and true label: 56
# Prediction result: [[ -5 -12  68]], and true label: 56
# Prediction result: [[  0 -15  66]], and true label: 56
# Prediction result: [[-3 -5 60]], and true label: 56
# Prediction result: [[-36  55  38]], and true label: 56
# Prediction result: [[ 7 21 25]], and true label: 56
# Prediction result: [[-12  60   9]], and true label: 56
# Prediction result: [[-19  64  13]], and true label: 56
# Prediction result: [[12 32 12]], and true label: 56
# Prediction result: [[-13  10  56]], and true label: 56
# Prediction result: [[-39  78  20]], and true label: 56
# Prediction result: [[-18  60  14]], and true label: 56
# Prediction result: [[-45  75  30]], and true label: 56
# Prediction result: [[-60  66  53]], and true label: 56
# Prediction result: [[-43  53  48]], and true label: 56
# Prediction result: [[  4 -34  79]], and true label: 56
# Prediction result: [[ 0 48  8]], and true label: 56
# Prediction result: [[-56  94  23]], and true label: 56
# Prediction result: [[-10  53  13]], and true label: 56
# Prediction result: [[-38  49  46]], and true label: 56
# Prediction result: [[-56 106  11]], and true label: 56
# Prediction result: [[-36  30  62]], and true label: 56
# Prediction result: [[12 47 -4]], and true label: 56
# Prediction result: [[-55  82  33]], and true label: 56
# Prediction result: [[-42  80  21]], and true label: 56
# Prediction result: [[-49  77  31]], and true label: 56
# Prediction result: [[-83 101  45]], and true label: 56
# Prediction result: [[-79  81  58]], and true label: 56
# Prediction result: [[-106  113   58]], and true label: 56
# Prediction result: [[-53  93  21]], and true label: 56
# Prediction result: [[-62 101  22]], and true label: 56
# Prediction result: [[-36  88   8]], and true label: 56
# Prediction result: [[-48  76  31]], and true label: 56
# Prediction result: [[-58  97  21]], and true label: 56
# Prediction result: [[-84  89  58]], and true label: 56
# Prediction result: [[-80 115  28]], and true label: 56
# Prediction result: [[-21 102 -21]], and true label: 56
# Prediction result: [[ 8 45  2]], and true label: 56
# Prediction result: [[-20  66  11]], and true label: 56
# test 1 all wav files is 96,
#  correct predict moaning:79.16666666666666
#  not predict moaning is 20.833333333333336
#    ******************   test-1 end   ******************

# %%
# scores = model.predict(sound, batch_size=len(sound), verbose=0);
# print(type(scores))
# print(scores.shape)

# for res in scores:
#     max_value = res.max()的
#     max_index = np.argmax(res)
#     print(f"max value:{max_value:.5f} and index is {max_index}")
#     print('\n'.join('{}: {:.5f}'.format(*k) for k in enumerate(res)))
