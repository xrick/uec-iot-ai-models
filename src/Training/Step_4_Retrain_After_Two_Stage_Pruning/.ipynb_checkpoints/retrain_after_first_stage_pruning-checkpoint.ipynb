# %%
import sys;
import os;
import glob;
import math;
import numpy as np;
import glob;
import random;
import time;
import torch;
import torch.optim as optim;
import torch.nn as nn;

sys.path.append(os.getcwd());
sys.path.append(os.path.abspath('../'));
sys.path.append(os.path.abspath('../../'));
# sys.path.append(os.path.join(os.getcwd(), 'torch/resources'));
import common.utils as U;
import common.opts as opts;
# import resources.models as models;
import th.resources.calculator as calc;
import common.tlopts as tlopts
# import resources.train_generator as train_generator;
import argparse
from itertools import repeat

# %%
import th.resources.models as models

# %%
from SharedLibs.datestring import genDataTimeStr, getDateStr

# %%
#Reproducibility
seed = 42;
random.seed(seed);
np.random.seed(seed);
torch.manual_seed(seed);
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed);
torch.backends.cudnn.deterministic = True;
torch.backends.cudnn.benchmark = False;

# %%
weight_pruned_model = "../../th/pruned_models/first_stage_pruning/pruning_time_2024021614_prunratio60.0/acdne_97.7_first_stage_prun_acc97.7272720336914_epoch_55_20240216150153.pt"

# %% [markdown]
# ## define the variables opt and set values

# %%
def getOpts():
    parser = argparse.ArgumentParser(description='Transfer Learning for ACDNet');
    parser.add_argument('--netType', default='ACDNetV2',  required=False);
    parser.add_argument('--data', default='../../datasets/CurrentUse/forOneClassModel_alarm/train/',  required=False);
    parser.add_argument('--dataset', required=False, default='uec_iot', choices=['2']);
    parser.add_argument('--BC', default=True, action='store_true', help='BC learning');
    parser.add_argument('--strongAugment', default=True,  action='store_true', help='Add scale and gain augmentation');
    #在ipynb中，不能使用parser.parse，要改用parser.parse_known_args()
    opt, unknown = parser.parse_known_args();
    return opt
    # opt = parser.parse_args();

# %% [markdown]
# ## Define the Generator

# %%
class TLGenerator():
    #Generates data for Keras
    def __init__(self, samples=None, labels=None, options=None, classes_dict=None):
        random.seed(42);
        #Initialization
        print(f"length of samples:{len(samples)}")
        self.data = [(samples[i], labels[i]) for i in range (0, len(samples))];
        self.opt = options;
        self.batch_size = options.batchSize;
        self.preprocess_funcs = self.preprocess_setup();
        self.mapdict = classes_dict

    def __len__(self):
        #Denotes the number of batches per epoch
        return int(np.floor(len(self.data) / self.batch_size));
        #return len(self.samples);

    def __getitem__(self, batchIndex):
        #Generate one batch of data
        batchX, batchY = self.generate_batch(batchIndex);
        batchX = np.expand_dims(batchX, axis=1);
        batchX = np.expand_dims(batchX, axis=3);
        return batchX, batchY

    def generate_batch(self, batchIndex):
        #Generates data containing batch_size samples
        sounds = [];
        labels = [];
        indexes = None;
        for i in range(self.batch_size):
            # Training phase of BC learning
            # Select two training examples
            while True:
                sound1, label1 = self.data[random.randint(0, len(self.data) - 1)]
                sound2, label2 = self.data[random.randint(0, len(self.data) - 1)]
                if label1 != label2:
                    break
            sound1 = self.preprocess(sound1)
            sound2 = self.preprocess(sound2)

            # Mix two examples
            r = np.array(random.random())
            sound = U.mix(sound1, sound2, r, self.opt.sr).astype(np.float32)
            # print(f"sound length after U.mix is {len(sound)}")
            # print(f"nClasses:{self.opt.nClasses}, type of mapdict:{type(self.mapdict)}, type of label1:{type(label1)}")
            eye = np.eye(self.opt.nClasses)
            idx1 = self.mapdict[label1]- 1
            idx2 = self.mapdict[label2] - 1
            label = (eye[idx1] * r + eye[idx2] * (1 - r)).astype(np.float32)
            # label = (eye[label1] * r + eye[label2] * (1 - r)).astype(np.float32)

            #For stronger augmentation
            sound = U.random_gain(6)(sound).astype(np.float32)
            # print(f"sound length after U.random_gain is {len(sound)}")
            sounds.append(sound);
            labels.append(label);

        sounds = np.asarray(sounds);
        labels = np.asarray(labels);
        # print(f"batchIndex is {batchIndex}, total sounds is {len(sounds)}")
        # print(f"labels in generate_batch is:\n{labels}")

        return sounds, labels;

    def preprocess_setup(self):
        funcs = []
        if self.opt.strongAugment:
            funcs += [U.random_scale(1.25)]

        funcs += [U.padding(self.opt.inputLength // 2),
                  U.random_crop(self.opt.inputLength),
                  U.normalize(32768.0)]
        return funcs

    def preprocess(self, sound):
        for f in self.preprocess_funcs:
            sound = f(sound)

        return sound;

# %% [markdown]
# ## Define Trainer

# %%
class ReTrainer:
    def __init__(self, opt=None, classes_dict=None):
        self.opt = opt;
        self.testX = None;
        self.testY = None;
        self.bestAcc = 0.0;
        self.bestAccEpoch = 0;
        self.trainGen = getTrainGen(opt,classes_dict=classes_dict)#train_generator.setup(opt, split);
        # self.opt.trainer = self;
        # self.trainGen = getTrainGen(self.opt, self.opt.splits)#train_generator.setup(self.opt, self.opt.split);
        # self.pretrainedmodelpath = "./resources/pretrained_models/acdnet20_20khz_fold4.h5"

    def Train(self):
        train_start_time = time.time();
        state = torch.load(weight_pruned_model)
        weights = state['weight']
        config = state['config']
        print(f"config is {config}")
        net = models.GetACDNetModel(input_len=30225, sr=20000, nclass=2, channel_config=config)
        net.load_state_dict(weights);
         #show the acdnet structures
        calc.summary(net,(1,1,30225))
        # net = getPrunedModel(pruned_model_path=pruned_acdnet)
        #print networks parameters' require_grade value
        for k_, v_ in net.named_parameters():
            print(f"{k_}:{v_.requires_grad}")
        print('ACDNet model has been prepared for training');

        calc.summary(net, (1,1,self.opt.inputLength));
        # net = net.cuda();
        # training_text = "Re-Training" if self.opt.retrain else "Training from Scratch";
        # print("{} has been started. You will see update after finishing every training epoch and validation".format(training_text));

        lossFunc = torch.nn.KLDivLoss(reduction='batchmean');
        optimizer = optim.SGD(net.parameters(), lr=self.opt.LR, weight_decay=self.opt.weightDecay, momentum=self.opt.momentum, nesterov=True);

        # self.opt.nEpochs = 1957 if self.opt.split == 4 else 2000;
        for epochIdx in range(self.opt.nEpochs):
            epoch_start_time = time.time();
            optimizer.param_groups[0]['lr'] = self.__get_lr(epochIdx+1);
            cur_lr = optimizer.param_groups[0]['lr'];
            running_loss = 0.0;
            running_acc = 0.0;
            n_batches = math.ceil(len(self.trainGen.data)/self.opt.batchSize);
            for batchIdx in range(n_batches):
                # with torch.no_grad():
                x,y = self.trainGen.__getitem__(batchIdx)
                x = torch.tensor(np.moveaxis(x, 3, 1)).to(self.opt.device);
                y = torch.tensor(y).to(self.opt.device);
                # zero the parameter gradients
                optimizer.zero_grad();

                # forward + backward + optimize
                # outputs = net(x);#in office and use cpu
                x = x.type(torch.FloatTensor) #use apple m2
                outputs = net(x)
                # in office use cpu, need to change to cuda
                # running_acc += (((outputs.data.argmax(dim=1) == y.argmax(dim=1))*1).float().mean()).item();
                # at home use apple m2
                res_y = y.argmax(dim=1)
                res_y = res_y.type(torch.FloatTensor)
                running_acc += ((( outputs.data.argmax(dim=1) == res_y)*1).float().mean()).item();
                y = y.type(torch.FloatTensor)
                
                loss = lossFunc(outputs.log(), y);
                loss.backward();
                optimizer.step();

                running_loss += loss.item();

            tr_acc = (running_acc / n_batches)*100;
            tr_loss = running_loss / n_batches;

            #Epoch wise validation Validation
            epoch_train_time = time.time() - epoch_start_time;

            net.eval();
            val_acc, val_loss = self.__validate(net, lossFunc);
            #Save best model
            self.__save_model(val_acc, epochIdx, net);
            self.__on_epoch_end(epoch_start_time, epoch_train_time, epochIdx, cur_lr, tr_loss, tr_acc, val_loss, val_acc);

            running_loss = 0;
            running_acc = 0;
            net.train();

        total_time_taken = time.time() - train_start_time;
        print("Execution finished in: {}".format(U.to_hms(total_time_taken)));

    def load_test_data(self):
        # data = np.load(os.path.join(self.opt.data, self.opt.dataset, 'test_data_{}khz/fold{}_test4000.npz'.format(self.opt.sr//1000, self.opt.split)), allow_pickle=True);
        data = np.load(self.opt.valData, allow_pickle=True);
        print(f"device is :{self.opt.device}")
        print(f"len of Y:{len(data['y'])}")
        # self.testX = torch.tensor(np.moveaxis(data['x'], 3, 1)).to(self.opt.device);
        dataX = np.moveaxis(data['x'], 3, 1).astype(np.float32);
        self.testX = torch.tensor(dataX).to(self.opt.device);
        self.testY = torch.tensor(data['y']).type(torch.float32).to(self.opt.device);

    def __get_lr(self, epoch):
        divide_epoch = np.array([self.opt.nEpochs * i for i in self.opt.schedule]);
        decay = sum(epoch > divide_epoch);
        if epoch <= self.opt.warmup:
            decay = 1;
        return self.opt.LR * np.power(0.1, decay);

    def __get_batch(self, index):
        x = self.trainX[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        y = self.trainY[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        return x.to(self.opt.device), y.to(self.opt.device);

    def __validate(self, net, lossFunc):
        if self.testX is None:
            self.load_test_data();
        net.eval();
        with torch.no_grad():
            y_pred = None;
            batch_size = len(self.testX);#(self.opt.batchSize//self.opt.nCrops)*self.opt.nCrops;
#             for idx in range(math.ceil(len(self.testX)/batch_size)):
#             for idx in range(len(self.testX)):
#             x = self.testX[idx*batch_size : (idx+1)*batch_size];
            x = self.testX[:];
            x = torch.tensor(x)
            x = x.type(torch.FloatTensor) # use apple mp2
            scores = net(x);
            y_pred = scores.data if y_pred is None else torch.cat((y_pred, scores.data));
            acc, loss = self.__compute_accuracy(y_pred, self.testY, lossFunc);
#         with torch.no_grad():
#             y_pred = None;
#             batch_size = (self.opt.batchSize//self.opt.nCrops)*self.opt.nCrops;
#             for idx in range(math.ceil(len(self.testX)/batch_size)):
#                 x = self.testX[idx*batch_size : (idx+1)*batch_size];
#                 scores = net(x);
#                 y_pred = scores.data if y_pred is None else torch.cat((y_pred, scores.data));

#             acc, loss = self.__compute_accuracy(y_pred, self.testY, lossFunc);
        net.train();
        return acc, loss;

    #Calculating average prediction (10 crops) and final accuracy
    def __compute_accuracy(self, y_pred, y_target, lossFunc):
        print(f"shape of y_pred:{y_pred.shape}");
        print(f"shape of y_target:{y_target.shape}");
        
        with torch.no_grad():
            #Reshape to shape theme like each sample comtains 10 samples, calculate mean and find theindices that has highest average value for each sample
            if self.opt.nCrops == 1:
                y_pred = y_pred.argmax(dim=1);
                y_target = y_target.argmax(dim=1);
            else:
                y_pred = (y_pred.reshape(y_pred.shape[0]//self.opt.nCrops, self.opt.nCrops, y_pred.shape[1])).mean(dim=1).argmax(dim=1);
                y_target = (y_target.reshape(y_target.shape[0]//self.opt.nCrops, self.opt.nCrops, y_target.shape[1])).mean(dim=1).argmax(dim=1);
                print(f"after: len of y_pred:{len(y_pred)}, len of y_target:{len(y_target)}")
            y_target = y_target.cpu() #use apple m2, in office use cuda
            acc = (((y_pred==y_target)*1).float().mean()*100).item();
            # valLossFunc = torch.nn.KLDivLoss();
            loss = lossFunc(y_pred.float().log(), y_target.float()).item();
            # loss = 0.0;
        return acc, loss;

    def __on_epoch_end(self, start_time, train_time, epochIdx, lr, tr_loss, tr_acc, val_loss, val_acc):
        epoch_time = time.time() - start_time;
        val_time = epoch_time - train_time;
        line = 'SP-{} Epoch: {}/{} | Time: {} (Train {}  Val {}) | Train: LR {}  Loss {:.2f}  Acc {:.2f}% | Val: Loss {:.2f}  Acc(top1) {:.2f}% | HA {:.2f}@{}\n'.format(
            self.opt.splits, epochIdx+1, self.opt.nEpochs, U.to_hms(epoch_time), U.to_hms(train_time), U.to_hms(val_time),
            lr, tr_loss, tr_acc, val_loss, val_acc, self.bestAcc, self.bestAccEpoch);
        # print(line)
        sys.stdout.write(line);
        sys.stdout.flush();

    def __save_model(self, acc, epochIdx, net):
        if acc > self.bestAcc:
            # dir = os.getcwd();
            # fname = "{}/torch/trained_models/{}_fold{}.pt";
            # old_model = fname.format(dir, self.opt.model_name.lower(), self.opt.split);
            # if os.path.isfile(old_model):
            #     os.remove(old_model);
            self.bestAcc = acc;
            self.bestAccEpoch = epochIdx +1;
            save_model_name = self.opt.model_name.format(acc, epochIdx, genDataTimeStr());
            save_model_fullpath = self.opt.saveDir + save_model_name;
            print(f"save model to {save_model_fullpath}")
            torch.save({'weight':net.state_dict(), 'config':net.ch_config}, save_model_fullpath);

# %%
def getTrainGen(opt=None, split=None, classes_dict=None):
    dataset = np.load(opt.trainData, allow_pickle=True);
    train_sounds = []
    train_labels = []
    train_sounds = dataset['fold{}'.format(1)].item()['sounds']
    train_labels = dataset['fold{}'.format(1)].item()['labels']
    trainGen = TLGenerator(train_sounds, train_labels, opt, classes_dict=classes_dict);
    trainGen.preprocess_setup();
    return trainGen

# %%
""" recording training settings and results
weight-pruning-ratio:0.7
final acc:
epoch:
opt.batchSize = 32;
opt.LR = 0.005;
opt.weightDecay = 5e-3;
opt.momentum = 0.004;
opt.nEpochs = 1000;
opt.schedule = [0.01, 0.03, 0.05];
opt.warmup = 20;
"""
# Out:
# ' recording training settings and results\nweight-pruning-ratio:0.7\nfinal acc:\nepoch:\nopt.batchSize = 32;\nopt.LR = 0.005;\nopt.weightDecay = 5e-3;\nopt.momentum = 0.004;\nopt.nEpochs = 1000;\nopt.schedule = [0.01, 0.03, 0.05];\nopt.warmup = 20;\n'

# %%
#define model save dir
save_dir = "../retrained_models_after_first_stage_pruning/pruning_time_{}_prunratio{}/".format(getDateStr(),0.6)
print(f"save dir is: {save_dir}")
# Out:
# save dir is: ../retrained_models_after_first_stage_pruning/pruning_time_2024021618_prunratio0.6/

# %%
def main(save_dir=None):
    map_dict_train = {
        52:1, #alarm
        99:2, #other_sounds
    };
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    opt = getOpts();
    opt.saveDir = save_dir;
    opt.trainData = "../../datasets/CurrentUse/forOneClassModel_alarm/train/trainSet_20240119002902.npz"
    opt.valData = "../../datasets/CurrentUse/forOneClassModel_alarm/test_val/final_val_test_npz/final_valSet_20240119004614.npz"
    #Leqarning settings
    opt.batchSize = 32;
    opt.LR = 0.05;
    opt.weightDecay = 5e-3;
    opt.momentum = 0.25;
    opt.nEpochs = 1000;
    opt.schedule = [0.1, 0.3, 0.5];
    opt.warmup = 10;
    opt.device="cuda:0";
    # if torch.backends.mps.is_available():
    #     opt.device="mps"; #for apple m2 gpu
    # elif torch.cuda.is_available():
    #     opt.device="cuda:0"; #for nVidia gpu
    # else:
    #     opt.device="cpu"
    print(f"***Use device:{opt.device}");
    # opt.device = torch.device("cuda:0" if  else "cpu");
    #Basic Net Settings
    opt.nClasses = 2
    opt.nFolds = 1;
    opt.splits = [i for i in range(1, opt.nFolds + 1)];
    opt.sr = 20000;
    opt.inputLength = 30225;
    #Test data
    opt.nCrops = 2;
    opt.model_name = "retrained_model_after_first_pruning_0.7ratio_acc{}_{}th_epoch_{}.pt"
    #Starting retraining process
    trainer = ReTrainer(opt=opt, classes_dict=map_dict_train);
    trainer.Train();

# %%
main(save_dir=save_dir)
# Out:
# ***Use device:cuda:0
# length of samples:325
# config is [8, 64, 32, 64, 64, 128, 128, 256, 256, 512, 512, 2]
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (64, 1, 7553)      2,560   19,335,680
#   BatchNorm2d-5     (64, 1, 7553)     (64, 1, 7553)        128            0
#          ReLu-6     (64, 1, 7553)     (64, 1, 7553)          0      483,392
#     MaxPool2d-7     (64, 1, 7553)      (64, 1, 151)          0      483,200
#       Permute-8      (64, 1, 151)      (1, 64, 151)          0            0
#        Conv2d-9      (1, 64, 151)     (32, 64, 151)        288    2,783,232
#  BatchNorm2d-10     (32, 64, 151)     (32, 64, 151)         64            0
#         ReLu-11     (32, 64, 151)     (32, 64, 151)          0      309,248
#    MaxPool2d-12     (32, 64, 151)      (32, 32, 75)          0      307,200
#       Conv2d-13      (32, 32, 75)      (64, 32, 75)     18,432   44,236,800
#  BatchNorm2d-14      (64, 32, 75)      (64, 32, 75)        128            0
#         ReLu-15      (64, 32, 75)      (64, 32, 75)          0      153,600
#       Conv2d-16      (64, 32, 75)      (64, 32, 75)     36,864   88,473,600
#  BatchNorm2d-17      (64, 32, 75)      (64, 32, 75)        128            0
#         ReLu-18      (64, 32, 75)      (64, 32, 75)          0      153,600
#    MaxPool2d-19      (64, 32, 75)      (64, 16, 37)          0      151,552
#       Conv2d-20      (64, 16, 37)     (128, 16, 37)     73,728   43,646,976
#  BatchNorm2d-21     (128, 16, 37)     (128, 16, 37)        256            0
#         ReLu-22     (128, 16, 37)     (128, 16, 37)          0       75,776
#       Conv2d-23     (128, 16, 37)     (128, 16, 37)    147,456   87,293,952
#  BatchNorm2d-24     (128, 16, 37)     (128, 16, 37)        256            0
#         ReLu-25     (128, 16, 37)     (128, 16, 37)          0       75,776
#    MaxPool2d-26     (128, 16, 37)      (128, 8, 18)          0       73,728
#       Conv2d-27      (128, 8, 18)      (256, 8, 18)    294,912   42,467,328
#  BatchNorm2d-28      (256, 8, 18)      (256, 8, 18)        512            0
#         ReLu-29      (256, 8, 18)      (256, 8, 18)          0       36,864
#       Conv2d-30      (256, 8, 18)      (256, 8, 18)    589,824   84,934,656
#  BatchNorm2d-31      (256, 8, 18)      (256, 8, 18)        512            0
#         ReLu-32      (256, 8, 18)      (256, 8, 18)          0       36,864
#    MaxPool2d-33      (256, 8, 18)       (256, 4, 9)          0       36,864
#       Conv2d-34       (256, 4, 9)       (512, 4, 9)  1,179,648   42,467,328
#  BatchNorm2d-35       (512, 4, 9)       (512, 4, 9)      1,024            0
#         ReLu-36       (512, 4, 9)       (512, 4, 9)          0       18,432
#       Conv2d-37       (512, 4, 9)       (512, 4, 9)  2,359,296   84,934,656
#  BatchNorm2d-38       (512, 4, 9)       (512, 4, 9)      1,024            0
#         ReLu-39       (512, 4, 9)       (512, 4, 9)          0       18,432
#    MaxPool2d-40       (512, 4, 9)       (512, 2, 4)          0       16,384
#       Conv2d-41       (512, 2, 4)         (2, 2, 4)      1,024        8,192
#  BatchNorm2d-42         (2, 2, 4)         (2, 2, 4)          4            0
#         ReLu-43         (2, 2, 4)         (2, 2, 4)          0           16
#    AvgPool2d-44         (2, 2, 4)         (2, 1, 1)          0           16
#      Flatten-45         (2, 1, 1)            (1, 2)          0            0
#       Linear-46            (1, 2)            (1, 2)          6            6
#      Softmax-47            (1, 2)            (1, 2)          0            2
# ==============================================================================
# Total Params: 4,708,162
# Total FLOPs : 544,222,072
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 17.96
# Total size (MB) : 18.08
# ------------------------------------------------------------------------------
#
# sfeb.0.weight:True
# sfeb.1.weight:True
# sfeb.1.bias:True
# sfeb.3.weight:True
# sfeb.4.weight:True
# sfeb.4.bias:True
# tfeb.0.weight:True
# tfeb.1.weight:True
# tfeb.1.bias:True
# tfeb.4.weight:True
# tfeb.5.weight:True
# tfeb.5.bias:True
# tfeb.7.weight:True
# tfeb.8.weight:True
# tfeb.8.bias:True
# tfeb.11.weight:True
# tfeb.12.weight:True
# tfeb.12.bias:True
# tfeb.14.weight:True
# tfeb.15.weight:True
# tfeb.15.bias:True
# tfeb.18.weight:True
# tfeb.19.weight:True
# tfeb.19.bias:True
# tfeb.21.weight:True
# tfeb.22.weight:True
# tfeb.22.bias:True
# tfeb.25.weight:True
# tfeb.26.weight:True
# tfeb.26.bias:True
# tfeb.28.weight:True
# tfeb.29.weight:True
# tfeb.29.bias:True
# tfeb.33.weight:True
# tfeb.34.weight:True
# tfeb.34.bias:True
# tfeb.38.weight:True
# tfeb.38.bias:True
# ACDNet model has been prepared for training
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (64, 1, 7553)      2,560   19,335,680
#   BatchNorm2d-5     (64, 1, 7553)     (64, 1, 7553)        128            0
#          ReLu-6     (64, 1, 7553)     (64, 1, 7553)          0      483,392
#     MaxPool2d-7     (64, 1, 7553)      (64, 1, 151)          0      483,200
#       Permute-8      (64, 1, 151)      (1, 64, 151)          0            0
#        Conv2d-9      (1, 64, 151)     (32, 64, 151)        288    2,783,232
#  BatchNorm2d-10     (32, 64, 151)     (32, 64, 151)         64            0
#         ReLu-11     (32, 64, 151)     (32, 64, 151)          0      309,248
#    MaxPool2d-12     (32, 64, 151)      (32, 32, 75)          0      307,200
#       Conv2d-13      (32, 32, 75)      (64, 32, 75)     18,432   44,236,800
#  BatchNorm2d-14      (64, 32, 75)      (64, 32, 75)        128            0
#         ReLu-15      (64, 32, 75)      (64, 32, 75)          0      153,600
#       Conv2d-16      (64, 32, 75)      (64, 32, 75)     36,864   88,473,600
#  BatchNorm2d-17      (64, 32, 75)      (64, 32, 75)        128            0
#         ReLu-18      (64, 32, 75)      (64, 32, 75)          0      153,600
#    MaxPool2d-19      (64, 32, 75)      (64, 16, 37)          0      151,552
#       Conv2d-20      (64, 16, 37)     (128, 16, 37)     73,728   43,646,976
#  BatchNorm2d-21     (128, 16, 37)     (128, 16, 37)        256            0
#         ReLu-22     (128, 16, 37)     (128, 16, 37)          0       75,776
#       Conv2d-23     (128, 16, 37)     (128, 16, 37)    147,456   87,293,952
#  BatchNorm2d-24     (128, 16, 37)     (128, 16, 37)        256            0
#         ReLu-25     (128, 16, 37)     (128, 16, 37)          0       75,776
#    MaxPool2d-26     (128, 16, 37)      (128, 8, 18)          0       73,728
#       Conv2d-27      (128, 8, 18)      (256, 8, 18)    294,912   42,467,328
#  BatchNorm2d-28      (256, 8, 18)      (256, 8, 18)        512            0
#         ReLu-29      (256, 8, 18)      (256, 8, 18)          0       36,864
#       Conv2d-30      (256, 8, 18)      (256, 8, 18)    589,824   84,934,656
#  BatchNorm2d-31      (256, 8, 18)      (256, 8, 18)        512            0
#         ReLu-32      (256, 8, 18)      (256, 8, 18)          0       36,864
#    MaxPool2d-33      (256, 8, 18)       (256, 4, 9)          0       36,864
#       Conv2d-34       (256, 4, 9)       (512, 4, 9)  1,179,648   42,467,328
#  BatchNorm2d-35       (512, 4, 9)       (512, 4, 9)      1,024            0
#         ReLu-36       (512, 4, 9)       (512, 4, 9)          0       18,432
#       Conv2d-37       (512, 4, 9)       (512, 4, 9)  2,359,296   84,934,656
#  BatchNorm2d-38       (512, 4, 9)       (512, 4, 9)      1,024            0
#         ReLu-39       (512, 4, 9)       (512, 4, 9)          0       18,432
#    MaxPool2d-40       (512, 4, 9)       (512, 2, 4)          0       16,384
#       Conv2d-41       (512, 2, 4)         (2, 2, 4)      1,024        8,192
#  BatchNorm2d-42         (2, 2, 4)         (2, 2, 4)          4            0
#         ReLu-43         (2, 2, 4)         (2, 2, 4)          0           16
#    AvgPool2d-44         (2, 2, 4)         (2, 1, 1)          0           16
#      Flatten-45         (2, 1, 1)            (1, 2)          0            0
#       Linear-46            (1, 2)            (1, 2)          6            6
#      Softmax-47            (1, 2)            (1, 2)          0            2
# ==============================================================================
# Total Params: 4,708,162
# Total FLOPs : 544,222,072
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 17.96
# Total size (MB) : 18.08
# ------------------------------------------------------------------------------
#
# device is :cuda:0
# len of Y:176
# /tmp/ipykernel_143216/3981960167.py:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# save model to ../retrained_models_after_first_stage_pruning/pruning_time_2024021618_prunratio0.6/retrained_model_after_first_pruning_0.7ratio_acc97.7272720336914_0th_epoch_20240216181902.pt
# SP-[1] Epoch: 1/1000 | Time: 0m06s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 85.80% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 2/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.06  Acc 86.93% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 3/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 84.38% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 4/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 87.78% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 5/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.06  Acc 85.80% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 6/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 87.50% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 7/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 87.50% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 8/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.06  Acc 88.64% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 9/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 10/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.05  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 11/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 12/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.20% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 13/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.93% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 14/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.06  Acc 87.22% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 15/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.64% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 16/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.06  Acc 84.66% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 17/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.06  Acc 86.93% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 18/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.36% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 19/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.77% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 20/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.62% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 21/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 85.80% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 22/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.50% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 23/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 24/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.65% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 25/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.49% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 26/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.64% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 27/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.06  Acc 85.23% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 28/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 85.23% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 29/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.36% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 30/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.78% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 31/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.78% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 32/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 33/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 90.62% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 34/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.22% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 35/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.20% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 36/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.77% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 37/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.65% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 38/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 39/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 86.65% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 40/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 86.65% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 41/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.92% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 42/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 92.90% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 43/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.20% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 44/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.92% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 45/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 46/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 47/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.06  Acc 86.36% | Val: Loss nan  Acc(top1) 93.18% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 48/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 49/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.35% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 50/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.78% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 51/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.03  Acc 90.06% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 52/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.08% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 53/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.22% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 54/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 55/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 56/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.50% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 57/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 58/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 59/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.35% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 60/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 61/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 62/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 63/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.50% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 64/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.22% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 65/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.50% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 66/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 86.08% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 67/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 87.50% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 68/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.35% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 69/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 90.62% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 70/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.50% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 71/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 72/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.08% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 73/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 74/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.49% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 75/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 76/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.22% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 77/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.03  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 78/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 79/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 80/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 81/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 91.19% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 82/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.36% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 83/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 84/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 84.66% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 85/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.49% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 86/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 87/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.03  Acc 92.05% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 88/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.92% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 89/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 88.64% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 90/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.35% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 91/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.62% | Val: Loss nan  Acc(top1) 94.32% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 92/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.08% | Val: Loss nan  Acc(top1) 97.73% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 93/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 94/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.35% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 95/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.50% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 96/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 97/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.05  Acc 86.36% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 98/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 99/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 89.49% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 100/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.05  Loss 0.04  Acc 87.22% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 101/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 88.64% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 102/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 103/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 86.65% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 104/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 89.20% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 105/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 91.48% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 106/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 89.49% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 107/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 108/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 88.64% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 109/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 110/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 92.05% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 111/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 112/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 113/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 95.45% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 114/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 115/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 89.49% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 116/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 117/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 118/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 88.92% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 119/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 92.61% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 120/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 89.20% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 121/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 92.90% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 122/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 93.47% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 123/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 88.64% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 124/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 125/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 126/1000 | Time: 0m05s (Train 0m04s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 127/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 128/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.06% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 129/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 130/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 91.76% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 131/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 92.33% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 132/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 133/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 88.92% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 134/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 135/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.04  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 136/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 90.62% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 137/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 138/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 0.005000000000000001  Loss 0.03  Acc 89.49% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# ...
# SP-[1] Epoch: 945/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 946/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 947/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 93.18% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 948/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.33% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 949/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 950/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 951/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 952/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.61% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 953/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.05% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 954/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 88.64% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 955/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 956/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 957/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.61% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 958/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 88.07% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 959/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 960/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 961/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 962/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 963/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 89.77% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 964/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.33% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 965/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 966/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 967/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.90% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 968/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 969/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 970/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 971/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.02  Acc 94.03% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 972/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 90.34% | Val: Loss nan  Acc(top1) 95.45% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 973/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 974/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 975/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 89.49% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 976/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 977/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 87.50% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 978/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 979/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.61% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 980/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.90% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 981/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 982/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 983/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 984/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 90.06% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 985/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 986/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 987/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 988/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 93.75% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 989/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.33% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 990/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.62% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 991/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.33% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 992/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.04  Acc 90.91% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 993/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.76% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 994/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 92.61% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 995/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.34% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 996/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.19% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 997/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 93.18% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 998/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 87.22% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 999/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 91.48% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# shape of y_pred:torch.Size([176, 2])
# shape of y_target:torch.Size([176, 2])
# after: len of y_pred:88, len of y_target:88
# SP-[1] Epoch: 1000/1000 | Time: 0m05s (Train 0m05s  Val 0m00s) | Train: LR 5.0000000000000016e-05  Loss 0.03  Acc 90.06% | Val: Loss nan  Acc(top1) 96.59% | HA 97.73@1
# Execution finished in: 1h34m
